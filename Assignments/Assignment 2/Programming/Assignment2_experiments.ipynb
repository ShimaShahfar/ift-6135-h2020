# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-806e6cc2-4341-4fb6-b2f0-9278df203331" name="files[]" multiple disabled />
#      <output id="result-806e6cc2-4341-4fb6-b2f0-9278df203331">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving run_exp.py to run_exp.py
# Saving solution.py to solution.py
# ...

# %% [markdown]
# # 3.1. RNN

# %%
# !python run_exp.py --model=RNN --optimizer=SGD --initial_lr=1.0 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=40 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3202.024722099304	speed (wps):11279.80825963773
# step: 30	loss (sum over all examples' seen this epoch):8390.92310667038	speed (wps):12343.866030456138
# step: 50	loss (sum over all examples' seen this epoch):13418.196496963501	speed (wps):12601.706843469576
# step: 70	loss (sum over all examples' seen this epoch):18367.932949066162	speed (wps):12711.005350149018
# step: 90	loss (sum over all examples' seen this epoch):23260.58177947998	speed (wps):12775.97122166164
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

rnn = 'RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0'
# gru = 'Probleme_4_1/GRU'
# transformer = 'Probleme_4_1/TRANSFORMER'

# dirs = [rnn,gru,transformer]
labels = ['RNN','GRU','Transformer']
colors = ['C'+str(i) for i in range(len(dirs))]

# Read learning_curves
train_ppls_all, val_ppls_all, train_losses_all, val_losses_all, times_all, epochs_all = [], [], [], [], [], []
# for r in dirs:
r = rnn
lc_path = os.path.join(r, 'learning_curves.npy')
learning_curve = np.load(lc_path)[()]
train_ppls, val_ppls, train_losses, val_losses, times = 
learning_curve['train_ppls'], learning_curve['val_ppls'], learning_curve['train_losses'], learning_curve['train_losses'], learning_curve['times']

epochs = np.arange(40)+1
times = np.cumsum(times)
train_ppls_all.append(train_ppls)
val_ppls_all.append(val_ppls)
train_losses_all.append(train_losses)
val_losses_all.append(val_losses)
epochs_all.append(epochs)
times_all.append(times)


plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
for i in range(1):
    plt.plot(epochs_all[i], train_ppls_all[i],color=colors[i], label=labels[i]+" Train PPL")
    plt.plot(epochs_all[i], val_ppls_all[i], '--', color=colors[i], label=labels[i]+" Val PPL")
    plt.legend()
    plt.ylim([0, 1000])
    plt.title("PPL with respect to Epochs")
    plt.ylabel("PPL")
    plt.xlabel("Epochs")

plt.subplot(212)
for i in range(1):
    plt.plot(times_all[i], train_ppls_all[i],color=colors[i], label=labels[i]+" Train PPL")
    plt.plot(times_all[i], val_ppls_all[i], '--',color=colors[i], label=labels[i]+" Val PPL")
    plt.legend()
    plt.ylim([0, 1000])
    plt.title("PPL with respect to Wall clock time")
    plt.ylabel("PPL")
    plt.xlabel("Wall clock time (seconds)")

plt.savefig('model_comparison.png')
plt.clf()
plt.close()

# %%
# !python run_exp.py --model=RNN --optimizer=SGD --initial_lr=1.0 --batch_size=20  --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=40 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3204.1203474998474	speed (wps):4265.629198035886
# step: 142	loss (sum over all examples' seen this epoch):35860.755965709686	speed (wps):4737.319241748336
# step: 274	loss (sum over all examples' seen this epoch):67335.68578243256	speed (wps):4749.89871505799
# step: 406	loss (sum over all examples' seen this epoch):98280.10989904404	speed (wps):4758.921563473623
# step: 538	loss (sum over all examples' seen this epoch):128819.79975223541	speed (wps):4762.1836174073405
# ...

# %%
# !python run_exp.py --model=RNN --optimizer=SGD --initial_lr=10.0 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3983.874192237854	speed (wps):12230.851602609355
# step: 30	loss (sum over all examples' seen this epoch):12746.96237564087	speed (wps):12679.506319717102
# step: 50	loss (sum over all examples' seen this epoch):22866.653203964233	speed (wps):12773.357459856506
# step: 70	loss (sum over all examples' seen this epoch):30924.54640865326	speed (wps):12829.589413277685
# step: 90	loss (sum over all examples' seen this epoch):38352.06593990326	speed (wps):12867.479845492462
# ...

# %%
# !python run_exp.py --model=RNN --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=40 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):2967.807378768921	speed (wps):12076.303237434282
# step: 30	loss (sum over all examples' seen this epoch):7724.38533782959	speed (wps):12528.183377841882
# step: 50	loss (sum over all examples' seen this epoch):12319.253120422363	speed (wps):12629.023023862403
# step: 70	loss (sum over all examples' seen this epoch):16758.694865703583	speed (wps):12669.984966002825
# step: 90	loss (sum over all examples' seen this epoch):21066.128232479095	speed (wps):12701.807246793569
# ...

# %%
# !python run_exp.py --model=RNN --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.8  --num_epochs=40 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3512.469644546509	speed (wps):12186.072595387664
# step: 30	loss (sum over all examples' seen this epoch):9077.372078895569	speed (wps):12606.238078982293
# step: 50	loss (sum over all examples' seen this epoch):14055.900928974152	speed (wps):12680.334463576819
# step: 70	loss (sum over all examples' seen this epoch):18834.435698986053	speed (wps):12725.96552750087
# step: 90	loss (sum over all examples' seen this epoch):23546.65204524994	speed (wps):12742.800577368074
# ...

# %%
# !zip -r RNN_SGD_model_1_40.zip RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
files.download('RNN_SGD_model_1_40.zip')
# Out:
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/ (stored 0%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/best_params.pt (deflated 8%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/learning_curves.npy (deflated 35%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/log.txt (deflated 71%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/exp_config.txt (deflated 44%)

# %%
# !zip -r RNN_SGD_model_2_40.zip RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
files.download('RNN_SGD_model_2_40.zip')
# Out:
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/ (stored 0%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/best_params.pt (deflated 8%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/learning_curves.npy (deflated 33%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/log.txt (deflated 71%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=1.0_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/exp_config.txt (deflated 44%)

# %%
# !zip -r RNN_SGD_model_3_20.zip RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0
files.download('RNN_SGD_model_3_20.zip')
# Out:
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/ (stored 0%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/learning_curves.npy (deflated 34%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/log.txt (deflated 72%)
#   adding: RNN_SGD_model=RNN_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)

# %%
# !zip -r RNN_ADAM_model_1_40.zip RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
files.download('RNN_ADAM_model_1_40.zip')
# Out:
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/ (stored 0%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/best_params.pt (deflated 7%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/learning_curves.npy (deflated 35%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/log.txt (deflated 73%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/exp_config.txt (deflated 44%)

# %%
# !zip -r RNN_ADAM_model_2_40.zip RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0
files.download('RNN_ADAM_model_2_40.zip')
# Out:
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/ (stored 0%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/best_params.pt (deflated 8%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/learning_curves.npy (deflated 35%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/log.txt (deflated 71%)
#   adding: RNN_ADAM_model=RNN_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.8_num_epochs=40_save_best_0/exp_config.txt (deflated 44%)

# %% [markdown]
# # 3.1. RNN Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

rnn = 'GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0'
gru = 'Probleme_4_1/GRU'
transformer = 'Probleme_4_1/TRANSFORMER'

dirs = [rnn,gru,transformer]
labels = ['RNN','GRU','Transformer']
colors = ['C'+str(i) for i in range(len(dirs))]

# Read learning_curves
train_ppls_all, val_ppls_all, epochs_all, times_all = [], [], [], []
# for r in dirs:
r = rnn
lc_path = os.path.join(r, 'learning_curves.npy')
a = np.load(lc_path)[()]
train_ppls, val_ppls, times= a['train_ppls'], a['val_ppls'],a['times']
epochs = np.arange(40)+1
times = np.cumsum(times)
train_ppls_all.append(train_ppls)
val_ppls_all.append(val_ppls)
epochs_all.append(epochs)
times_all.append(times)


plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
for i in range(len(dirs)):
    plt.plot(epochs_all[i], train_ppls_all[i],color=colors[i], label=labels[i]+" Train PPL")
    plt.plot(epochs_all[i], val_ppls_all[i], '--', color=colors[i], label=labels[i]+" Val PPL")
    plt.legend()
    plt.ylim([0, 1000])
    plt.title("PPL with respect to Epochs")
    plt.ylabel("PPL")
    plt.xlabel("Epochs")

plt.subplot(212)
for i in range(len(dirs)):
    plt.plot(times_all[i], train_ppls_all[i],color=colors[i], label=labels[i]+" Train PPL")
    plt.plot(times_all[i], val_ppls_all[i], '--',color=colors[i], label=labels[i]+" Val PPL")
    plt.legend()
    plt.ylim([0, 1000])
    plt.title("PPL with respect to Wall clock time")
    plt.ylabel("PPL")
    plt.xlabel("Wall clock time (seconds)")

plt.savefig('model_comparison.png')
plt.clf()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f767e3a2b815> in <module>()
#      16 r = rnn
#      17 lc_path = os.path.join(r, 'learning_curves.npy')
# ---> 18 a = np.load(lc_path)[()]
#      19 train_ppls, val_ppls, times= a['train_ppls'], a['val_ppls'],a['times']
#      20 epochs = np.arange(40)+1
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy'

# %% [markdown]
# # 3.2. GRU

# %%
# !python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3352.6378655433655	speed (wps):12304.985133668395
# step: 30	loss (sum over all examples' seen this epoch):8353.2080078125	speed (wps):13206.122599433495
# step: 50	loss (sum over all examples' seen this epoch):13020.199403762817	speed (wps):13412.849310253003
# step: 70	loss (sum over all examples' seen this epoch):17552.3414850235	speed (wps):13538.502339218134
# step: 90	loss (sum over all examples' seen this epoch):21973.41446876526	speed (wps):13606.282426885266
# ...

# %%
# !zip -r GRU_ADAM_model_1_20.zip GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
files.download('GRU_ADAM_model_1_20.zip')
# Out:
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/ (stored 0%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/best_params.pt (deflated 7%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/log.txt (deflated 71%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)
# ...

# %%
# !python run_exp.py --model=GRU --optimizer=SGD  --initial_lr=10.0  --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3497.111749649048	speed (wps):17998.864062121615
# step: 30	loss (sum over all examples' seen this epoch):8882.320535182953	speed (wps):18722.530608988774
# step: 50	loss (sum over all examples' seen this epoch):14013.512525558472	speed (wps):18895.93829910433
# step: 70	loss (sum over all examples' seen this epoch):19009.351851940155	speed (wps):18989.925619800008
# step: 90	loss (sum over all examples' seen this epoch):23921.52185678482	speed (wps):18991.206872355095
# ...

# %%
# !zip -r GRU_SGD_model_1.zip GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
files.download('GRU_SGD_model_1.zip')
# Out:
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/ (stored 0%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/log.txt (deflated 70%)
#   adding: GRU_SGD_model=GRU_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)

# %%
# !python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=20 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3247.0320105552673	speed (wps):2833.6060208074705
# step: 142	loss (sum over all examples' seen this epoch):33373.27960729599	speed (wps):3005.6763486114055
# step: 274	loss (sum over all examples' seen this epoch):62039.660646915436	speed (wps):3011.0772139947917
# step: 406	loss (sum over all examples' seen this epoch):89646.09147548676	speed (wps):3015.9075705458536
# step: 538	loss (sum over all examples' seen this epoch):116894.94195699692	speed (wps):3018.043652011425
# ...

# %%
# !zip -r GRU_ADAM_model_2_20.zip GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
files.download('GRU_ADAM_model_2_20.zip')
# Out:
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/ (stored 0%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/best_params.pt (deflated 7%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy (deflated 33%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/log.txt (deflated 71%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=20_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)

# %% [markdown]
# # 3.3. GRU - Part2

# %%
# !python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=256 --num_layers=2 --dp_keep_prob=0.2 --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3429.4107341766357	speed (wps):14184.4455694354
# step: 30	loss (sum over all examples' seen this epoch):8656.673014163971	speed (wps):15364.844287262174
# step: 50	loss (sum over all examples' seen this epoch):13497.045731544495	speed (wps):15598.51980421136
# step: 70	loss (sum over all examples' seen this epoch):18243.860099315643	speed (wps):15750.009752173297
# step: 90	loss (sum over all examples' seen this epoch):22941.34441614151	speed (wps):15818.414732046735
# ...

# %%
# !zip -r GRU_ADAM_model_33_1.zip GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0
files.download('GRU_ADAM_model_33_1.zip')
# Out:
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0/ (stored 0%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0/best_params.pt (deflated 7%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0/log.txt (deflated 70%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=256_num_layers=2_dp_keep_prob=0.2_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)

# %%
# !python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=2048 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):4938.143630027771	speed (wps):4484.988986899325
# step: 30	loss (sum over all examples' seen this epoch):9558.057563304901	speed (wps):4505.676168050287
# step: 50	loss (sum over all examples' seen this epoch):13988.843085765839	speed (wps):4509.648769445076
# step: 70	loss (sum over all examples' seen this epoch):18277.650575637817	speed (wps):4508.493709145031
# step: 90	loss (sum over all examples' seen this epoch):22457.92088508606	speed (wps):4508.260651876469
# ...

# %%
# !zip -r GRU_ADAM_model_33_2.zip GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1
files.download('GRU_ADAM_model_33_2.zip')
# Out:
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1/ (stored 0%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1/best_params.pt (deflated 7%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1/learning_curves.npy (deflated 34%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1/log.txt (deflated 72%)
# updating: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_1/exp_config.txt (deflated 45%)
# ----------------------------------------
# ...

# %%
# !python run_exp.py --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=4 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3051.4411187171936	speed (wps):10038.188776243636
# step: 30	loss (sum over all examples' seen this epoch):7806.392388343811	speed (wps):10350.828623805477
# step: 50	loss (sum over all examples' seen this epoch):12462.487607002258	speed (wps):10394.548496610283
# step: 70	loss (sum over all examples' seen this epoch):17014.482312202454	speed (wps):10401.190324263482
# step: 90	loss (sum over all examples' seen this epoch):21486.895956993103	speed (wps):10412.588248546233
# ...

# %%
# !zip -r GRU_ADAM_model_33_3.zip GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0
files.download('GRU_ADAM_model_33_3.zip')
# Out:
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0/ (stored 0%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0/best_params.pt (deflated 7%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0/log.txt (deflated 70%)
#   adding: GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_save_best_0/exp_config.txt (deflated 45%)

# %% [markdown]
# # 3.4. Transformer

# %%
# !python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512  --num_layers=6 --dp_keep_prob=0.9 --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3297.959794998169	speed (wps):13594.83952101141
# step: 30	loss (sum over all examples' seen this epoch):8695.768718719482	speed (wps):13910.92449715718
# step: 50	loss (sum over all examples' seen this epoch):13604.101519584656	speed (wps):13968.654831714524
# step: 70	loss (sum over all examples' seen this epoch):18239.37247991562	speed (wps):13985.85424106858
# step: 90	loss (sum over all examples' seen this epoch):22781.695067882538	speed (wps):13993.145439856027
# ...

# %%
# !zip -r TRANSFORMER_ADAM_model_34_1.zip TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0
files.download('TRANSFORMER_ADAM_model_34_1.zip')
# Out:
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/ (stored 0%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/log.txt (deflated 71%)
# ...

# %%
# !python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512  --num_layers=2 --dp_keep_prob=0.9 --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.9_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3358.6380195617676	speed (wps):27503.68036350925
# step: 30	loss (sum over all examples' seen this epoch):8847.397973537445	speed (wps):28430.6853333073
# step: 50	loss (sum over all examples' seen this epoch):13821.886260509491	speed (wps):28575.89904604228
# step: 70	loss (sum over all examples' seen this epoch):18488.905227184296	speed (wps):28621.94510787731
# step: 90	loss (sum over all examples' seen this epoch):23048.39703321457	speed (wps):28633.977892139872
# ...

# %%
# !zip -r TRANSFORMER_ADAM_model_34_2.zip TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.9_num_epochs=20_save_best_0
files.download('TRANSFORMER_ADAM_model_34_2.zip')
# Out:
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.9_num_epochs=20_save_best_0/ (stored 0%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.9_num_epochs=20_save_best_0/best_params.pt (deflated 8%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.9_num_epochs=20_save_best_0/learning_curves.npy (deflated 35%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.9_num_epochs=20_save_best_0/log.txt (deflated 71%)
# ...

# %%
# !python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=2048 --num_layers=2 --dp_keep_prob=0.6 --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.6_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):2986.7411732673645	speed (wps):6856.396952147829
# step: 30	loss (sum over all examples' seen this epoch):7625.420138835907	speed (wps):6952.83421701217
# step: 50	loss (sum over all examples' seen this epoch):12198.959662914276	speed (wps):6954.634959064653
# step: 70	loss (sum over all examples' seen this epoch):16674.48165655136	speed (wps):6941.8451859671795
# step: 90	loss (sum over all examples' seen this epoch):21046.091475486755	speed (wps):6922.9079550342085
# ...

# %%
# !zip -r TRANSFORMER_ADAM_model_34_3.zip TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.6_num_epochs=20_save_best_0
files.download('TRANSFORMER_ADAM_model_34_3.zip')
# Out:
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.6_num_epochs=20_save_best_0/ (stored 0%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.6_num_epochs=20_save_best_0/exp_config.txt (deflated 46%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.6_num_epochs=20_save_best_0/learning_curves.npy (deflated 34%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=2048_num_layers=2_dp_keep_prob=0.6_num_epochs=20_save_best_0/.ipynb_checkpoints/ (stored 0%)
# ...

# %%
# !python run_exp.py --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=1024 --num_layers=6 --dp_keep_prob=0.9 --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=1024_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3067.4840593338013	speed (wps):7136.940918113913
# step: 30	loss (sum over all examples' seen this epoch):7836.043701171875	speed (wps):7134.9682824870815
# step: 50	loss (sum over all examples' seen this epoch):12399.925127029419	speed (wps):7137.347405826319
# step: 70	loss (sum over all examples' seen this epoch):16864.57943201065	speed (wps):7128.918050158052
# step: 90	loss (sum over all examples' seen this epoch):21213.444755077362	speed (wps):7105.591966557414
# ...

# %%
# !zip -r TRANSFORMER_ADAM_model_34_4.zip TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=1024_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0
files.download('TRANSFORMER_ADAM_model_34_4.zip')
# Out:
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=1024_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/ (stored 0%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=1024_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/exp_config.txt (deflated 46%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=1024_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/learning_curves.npy (deflated 34%)
#   adding: TRANSFORMER_ADAM_model=TRANSFORMER_optimizer=ADAM_initial_lr=0.0001_batch_size=128_seq_len=35_hidden_size=1024_num_layers=6_dp_keep_prob=0.9_num_epochs=20_save_best_0/.ipynb_checkpoints/ (stored 0%)
# ...
